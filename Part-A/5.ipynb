# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print("Enter incomplete prompt (type 'exit' to quit):\n")

while True:
    prompt = input("Input: ")
    
    if prompt.lower() == "exit":
        print("Bye!")
        break
    
    result = generator(prompt, max_length=50, num_return_sequences=1)
    
    print("\nCompleted Text:\n", result[0]['generated_text'])
    print("\n" + "-"*40 + "\n")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter incomplete prompt (type 'exit' to quit):
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print("Enter incomplete prompt (type 'exit' to quit):\n")

prompt ="Artificial Intelligence is transforming education by"
        
result = generator(prompt, max_length=50, num_return_sequences=1)
    
print("\nCompleted Text:\n", result[0]['generated_text'])
print("\n" + "-"*40 + "\n")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Enter incomplete prompt (type 'exit' to quit):
#
#
# Completed Text:
#  Artificial Intelligence is transforming education by bringing it into the arena of the 21st century. Google has launched its own research program, Google Brain, led by Prof. Paul Wolfram, a University of North Carolina professor of psychology.
#
# "It's about teaching people the skills they need to succeed as individuals and help them to make better decisions," said Dr. Wolfram. "It's a very exciting time for us as a society."
#
# Google and other companies are investing heavily in artificial intelligence, which has been linked to social problems and problems with jobs and economic growth. In a previous paper, researchers described the research as a "transformational paradigm shift" in research on artificial intelligence.
#
# "It's a powerful new field, and we are seeing the results in a number of ways," said Dr. Wolfram. "And I think it will also be important to understand the implications of this for the way we think about and use AI."
#
# Scientists have long been intrigued by artificial intelligence. In 2008, researchers estimated that there were about 1 billion jobs in the US.
#
# In the latest study, the team of Dr. Wolfram and Dr. Bader-Alesen found that the brain of people with autism is more similar to that of those with a normal brain,
#
# ----------------------------------------
