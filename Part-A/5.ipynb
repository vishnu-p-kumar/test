# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print("Enter incomplete prompt (type 'exit' to quit):\n")

while True:
    prompt = input("Input: ")
    
    if prompt.lower() == "exit":
        print("Bye!")
        break
    
    result = generator(prompt, max_length=50, num_return_sequences=1)
    
    print("\nCompleted Text:\n", result[0]['generated_text'])
    print("\n" + "-"*40 + "\n")
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# Enter incomplete prompt (type 'exit' to quit):
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Completed Text:
#  The "Nuclear War" has reached a tipping point.
#
# Two years ago, during one of the most dramatic nuclear crises in the world, the US military had to withdraw from North Korea. The US military had already been conducting a large-scale test of its nuclear arsenal. By December, North Korean leader Kim Jong-un had declared his nuclear plan to be complete.
#
# The US military is now focused on its "counter-terrorism" mission. In addition to its "counter-terrorism" forces, its military also conducts its nuclear weapons programs.
#
# The nuclear crisis is a very serious issue, even if the US does not control every aspect of it. However, the nuclear war will only increase in intensity, not decrease.
#
# In 2014, North Korea announced it would test a nuclear weapon to test the possibility of a non-proliferation treaty. The US responded by launching artillery and artillery shells at North Korean forces.
#
# This is a major escalation of tensions within the US and many other countries. The US was forced to withdraw from the Korean Peninsula to prevent a nuclear war.
#
# It is important to remember that the US has been involved in the nuclear program for centuries.
#
# The US was the second largest customer of military technology
#
# ----------------------------------------
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Completed Text:
#  3.5" thick matte black base
#
# Nibs
#
# The Nibs are a great value and should be bought at the same time as the other two, but in the case of the Titanium ones. Both are great value for the money and will set you back a half a ton.
#
# Both are fantastic for what you get out of the Nibs, and both work quite well together. The Titanium Nibs have a nice matte black base and the Titanium Nibs have a matte black base with a matte black surface. The Titanium Nibs have a nice matte black base and have a matte black coating. The Titanium Nibs have a matte black finish.
#
# The Nibs are super durable and are very easy to remove. It is easy to remove the Nibs without any difficulty and will easily be removed if you want it. If you remove it from your home, you may want to remove it from the driveway. Once removed, you can remove the Nibs from your garage by pressing the wrench on the Nib.
#
# 3.5" thick matte black base
#
# Nibs
#
# The Nibs are a great value and should be bought at the same time as the other two
#
# ----------------------------------------
