# %%
import torch
from diffusers import StableDiffusionPipeline
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"

model_id = "runwayml/stable-diffusion-v1-5"

pipe = StableDiffusionPipeline.from_pretrained(model_id)
pipe = pipe.to(device)

prompt = input("Enter text prompt: ")

result = pipe(prompt)

image = result.images[0]

image.save("generated_image.png")

plt.imshow(image)
plt.axis("off")
plt.title("Generated Image")
plt.show()

print("Image saved as generated_image.png")
# Out:
# W0410 06:33:59.592558 10660 site-packages\torch\distributed\elastic\multiprocessing\redirects.py:29] NOTE: Redirects are currently not supported in Windows or MacOs.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1010, in _LazyModule._get_module(self, module_name)
#    1009 try:
# -> 1010     return importlib.import_module("." + module_name, self.__name__)
#    1011 except Exception as e:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\loaders\lora_pipeline.py:34
#      21 from ..utils import (
#      22     USE_PEFT_BACKEND,
#      23     deprecate,
#    (...)
#      32     logging,
#      33 )
# ---> 34 from .lora_base import (  # noqa
#      35     LORA_WEIGHT_NAME,
#      36     LORA_WEIGHT_NAME_SAFE,
#      37     LoraBaseMixin,
#      38     _fetch_state_dict,
#      39     _load_lora_into_text_encoder,
#      40     _pack_dict_with_prefix,
#      41 )
#      42 from .lora_conversion_utils import (
#      43     _convert_bfl_flux_control_lora_to_diffusers,
#      44     _convert_fal_kontext_lora_to_diffusers,
#    (...)
#      59     _maybe_map_sgm_blocks_to_diffusers,
#      60 )
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\loaders\lora_base.py:57
#      56 if is_peft_available():
# ---> 57     from peft.tuners.tuners_utils import BaseTunerLayer
#      59 if is_accelerate_available():
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\peft\__init__.py:17
#      15 __version__ = "0.18.1"
# ---> 17 from .auto import (
#      18     MODEL_TYPE_TO_PEFT_MODEL_MAPPING,
#      19     AutoPeftModel,
#      20     AutoPeftModelForCausalLM,
#      21     AutoPeftModelForFeatureExtraction,
#      22     AutoPeftModelForQuestionAnswering,
#      23     AutoPeftModelForSeq2SeqLM,
#      24     AutoPeftModelForSequenceClassification,
#      25     AutoPeftModelForTokenClassification,
#      26 )
#      27 from .config import PeftConfig, PromptLearningConfig
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\peft\auto.py:31
#      21 from transformers import (
#      22     AutoModel,
#      23     AutoModelForCausalLM,
#    (...)
#      28     AutoTokenizer,
#      29 )
# ---> 31 from .config import PeftConfig
#      32 from .peft_model import (
#      33     PeftModel,
#      34     PeftModelForCausalLM,
#    (...)
#      39     PeftModelForTokenClassification,
#      40 )
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\peft\config.py:30
#      28 from peft import __version__
# ---> 30 from .utils import CONFIG_NAME, PeftType, TaskType
#      33 # we expect at least these keys to be present in a PEFT adapter_config.json
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\peft\utils\__init__.py:16
#      15 from .integrations import is_transformers_ge_v5, map_cache_to_layer_device_map
# ---> 16 from .loftq_utils import replace_lora_weights_loftq
#      17 from .other import (
#      18     CONFIG_NAME,
#      19     INCLUDE_LINEAR_LAYERS_SHORTHAND,
#    (...)
#      66     transpose,
#      67 )
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\peft\utils\loftq_utils.py:25
#      24 import torch
# ---> 25 from accelerate.utils.memory import clear_device_cache
#      26 from huggingface_hub import snapshot_download
#
# ImportError: cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\accelerate\utils\memory.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1010, in _LazyModule._get_module(self, module_name)
#    1009 try:
# -> 1010     return importlib.import_module("." + module_name, self.__name__)
#    1011 except Exception as e:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:883, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\pipelines\stable_diffusion\pipeline_stable_diffusion.py:24
#      23 from ...image_processor import PipelineImageInput, VaeImageProcessor
# ---> 24 from ...loaders import FromSingleFileMixin, IPAdapterMixin, StableDiffusionLoraLoaderMixin, TextualInversionLoaderMixin
#      25 from ...models import AutoencoderKL, ImageProjection, UNet2DConditionModel
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1000, in _LazyModule.__getattr__(self, name)
#     999 elif name in self._class_to_module.keys():
# -> 1000     module = self._get_module(self._class_to_module[name])
#    1001     value = getattr(module, name)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1012, in _LazyModule._get_module(self, module_name)
#    1011 except Exception as e:
# -> 1012     raise RuntimeError(
#    1013         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1014         f" traceback):\n{e}"
#    1015     ) from e
#
# RuntimeError: Failed to import diffusers.loaders.lora_pipeline because of the following error (look up to see its traceback):
# cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\accelerate\utils\memory.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 2
#       1 import torch
# ----> 2 from diffusers import StableDiffusionPipeline
#       3 import matplotlib.pyplot as plt
#       5 device = "cuda" if torch.cuda.is_available() else "cpu"
#
# File <frozen importlib._bootstrap>:1075, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1001, in _LazyModule.__getattr__(self, name)
#     999 elif name in self._class_to_module.keys():
#    1000     module = self._get_module(self._class_to_module[name])
# -> 1001     value = getattr(module, name)
#    1002 else:
#    1003     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1001, in _LazyModule.__getattr__(self, name)
#     999 elif name in self._class_to_module.keys():
#    1000     module = self._get_module(self._class_to_module[name])
# -> 1001     value = getattr(module, name)
#    1002 else:
#    1003     raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1000, in _LazyModule.__getattr__(self, name)
#     998     value = self._get_module(name)
#     999 elif name in self._class_to_module.keys():
# -> 1000     module = self._get_module(self._class_to_module[name])
#    1001     value = getattr(module, name)
#    1002 else:
#
# File c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\diffusers\utils\import_utils.py:1012, in _LazyModule._get_module(self, module_name)
#    1010     return importlib.import_module("." + module_name, self.__name__)
#    1011 except Exception as e:
# -> 1012     raise RuntimeError(
#    1013         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1014         f" traceback):\n{e}"
#    1015     ) from e
#
# RuntimeError: Failed to import diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion because of the following error (look up to see its traceback):
# Failed to import diffusers.loaders.lora_pipeline because of the following error (look up to see its traceback):
# cannot import name 'clear_device_cache' from 'accelerate.utils.memory' (c:\Users\vishn\AppData\Local\Programs\Python\Python310\lib\site-packages\accelerate\utils\memory.py)
